# %%
#import library
import psycopg2
import pandas as pd
# Out:
# /home/chenjie/anaconda3/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %% [markdown]
# ### connect using psycopg2

# %%
conn = psycopg2.connect("dbname = BasketballStats user = chenjie password = lcj53242 \
                        host = newbballserver.ctkmtyhjwqb1.us-east-2.rds.amazonaws.com")

# %%
# activate connection cursor
cur = conn.cursor()

# %%
# create player_play_types(we use view name player_play_types for further work
Q1 = """
        WITH Stat1 as (
    SELECT p1.player_name as player_name,p1.player_id as player_id, pa1.percentage_of_time as PR_Ball_Handler
    FROM player p1,player_average pa1, format f1, category c1, element e1
    WHERE p1.player_id = pa1.player_id AND f1.format_id = pa1.format_id 
    AND f1.format_name= 'Offensive' AND c1.category_id = pa1.category_id
    AND c1.category_name = 'Play Types' AND e1.element_id = pa1.element_id
    AND e1.element_name = 'P&R Ball Handler' 
    ),
        Stat2 as (
    SELECT p2.player_name as player_name,p2.player_id as player_id, pa2.percentage_of_time as Transition
    FROM player p2,player_average pa2, format f2, category c2, element e2
    WHERE p2.player_id = pa2.player_id AND f2.format_id = pa2.format_id 
    AND f2.format_name= 'Offensive' AND c2.category_id = pa2.category_id
    AND c2.category_name = 'Play Types' AND e2.element_id = pa2.element_id
    AND e2.element_name = 'Transition' 
    ),
        Stat3 as (
    SELECT p3.player_name as player_name,p3.player_id as player_id, pa3.percentage_of_time as Isolation
    FROM player p3,player_average pa3, format f3, category c3, element e3
    WHERE p3.player_id = pa3.player_id AND f3.format_id = pa3.format_id 
    AND f3.format_name= 'Offensive' AND c3.category_id = pa3.category_id
    AND c3.category_name = 'Play Types' AND e3.element_id = pa3.element_id
    AND e3.element_name = 'Isolation' 
    ),
        Stat4 as (
    SELECT p4.player_name as player_name,p4.player_id as player_id, pa4.percentage_of_time as Spot_Up
    FROM player p4,player_average pa4, format f4, category c4, element e4
    WHERE p4.player_id = pa4.player_id AND f4.format_id = pa4.format_id 
    AND f4.format_name= 'Offensive' AND c4.category_id = pa4.category_id
    AND c4.category_name = 'Play Types' AND e4.element_id = pa4.element_id
    AND e4.element_name = 'Spot Up' 
    ),
        Stat5 as (
    SELECT p5.player_name as player_name,p5.player_id as player_id, pa5.percentage_of_time as Hand_Off
    FROM player p5,player_average pa5, format f5, category c5, element e5
    WHERE p5.player_id = pa5.player_id AND f5.format_id = pa5.format_id 
    AND f5.format_name= 'Offensive' AND c5.category_id = pa5.category_id
    AND c5.category_name = 'Play Types' AND e5.element_id = pa5.element_id
    AND e5.element_name = 'Hand Off' 
    ),
        Stat6 as (
    SELECT p6.player_name as player_name,p6.player_id as player_id, pa6.percentage_of_time as Offensive_Rebounds
    FROM player p6,player_average pa6, format f6, category c6, element e6
    WHERE p6.player_id = pa6.player_id AND f6.format_id = pa6.format_id 
    AND f6.format_name= 'Offensive' AND c6.category_id = pa6.category_id
    AND c6.category_name = 'Play Types' AND e6.element_id = pa6.element_id
    AND e6.element_name = 'Offensive Rebounds (put backs)' 
    ),
        Stat7 as (
    SELECT p7.player_name as player_name,p7.player_id as player_id, pa7.percentage_of_time as Off_Screen
    FROM player p7,player_average pa7, format f7, category c7, element e7
    WHERE p7.player_id = pa7.player_id AND f7.format_id = pa7.format_id 
    AND f7.format_name= 'Offensive' AND c7.category_id = pa7.category_id
    AND c7.category_name = 'Play Types' AND e7.element_id = pa7.element_id
    AND e7.element_name = 'Off Screen' 
    ),
        Stat8 as (
    SELECT p8.player_name as player_name,p8.player_id as player_id, pa8.percentage_of_time as Cut
    FROM player p8,player_average pa8, format f8, category c8, element e8
    WHERE p8.player_id = pa8.player_id AND f8.format_id = pa8.format_id 
    AND f8.format_name= 'Offensive' AND c8.category_id = pa8.category_id
    AND c8.category_name = 'Play Types' AND e8.element_id = pa8.element_id
    AND e8.element_name = 'Cut' 
    ), 
        Stat9 as (
    SELECT p9.player_name as player_name,p9.player_id as player_id, pa9.percentage_of_time as Post_Up
    FROM player p9,player_average pa9, format f9, category c9, element e9
    WHERE p9.player_id = pa9.player_id AND f9.format_id = pa9.format_id 
    AND f9.format_name= 'Offensive' AND c9.category_id = pa9.category_id
    AND c9.category_name = 'Play Types' AND e9.element_id = pa9.element_id
    AND e9.element_name = 'Post-Up' 
    ),
        Stat10 as (
    SELECT p10.player_name as player_name,p10.player_id as player_id, pa10.percentage_of_time as PR_Roll_Man
    FROM player p10,player_average pa10, format f10, category c10, element e10
    WHERE p10.player_id = pa10.player_id AND f10.format_id = pa10.format_id 
    AND f10.format_name= 'Offensive' AND c10.category_id = pa10.category_id
    AND c10.category_name = 'Play Types' AND e10.element_id = pa10.element_id
    AND e10.element_name = 'P&R Roll Man' 
    ),
        Stat11 as (
    SELECT p11.player_name as player_name,p11.player_id as player_id, pa11.percentage_of_time as Miscellaneous
    FROM player p11,player_average pa11, format f11, category c11, element e11
    WHERE p11.player_id = pa11.player_id AND f11.format_id = pa11.format_id 
    AND f11.format_name= 'Offensive' AND c11.category_id = pa11.category_id
    AND c11.category_name = 'Play Types' AND e11.element_id = pa11.element_id
    AND e11.element_name = 'Miscellaneous' 
    )

    Select Stat1.*,Stat2.Transition,Stat3.Isolation,Stat4.Spot_Up,Stat5.Hand_Off,
    Stat6.Offensive_Rebounds,Stat7.Off_Screen,Stat8.Cut,
    Stat9.Post_Up,Stat10.PR_Roll_Man,Stat11.Miscellaneous
    FROM Stat1,Stat2,Stat3,Stat4,Stat5,Stat6,Stat7,Stat8,Stat9,Stat10,Stat11
    WHERE 
    Stat1.player_id = Stat2.player_id AND Stat1.player_id = Stat3.player_id AND 
    Stat1.player_id = Stat4.player_id AND Stat1.player_id = Stat5.player_id AND
    Stat1.player_id = Stat6.player_id AND Stat1.player_id = Stat7.player_id AND
    Stat1.player_id = Stat8.player_id AND Stat1.player_id = Stat9.player_id AND 
    Stat1.player_id = Stat10.player_id AND Stat1.player_id = Stat11.player_id AND

    Stat2.player_id = Stat3.player_id AND Stat2.player_id = Stat4.player_id AND 
    Stat2.player_id = Stat5.player_id AND Stat2.player_id = Stat6.player_id AND 
    Stat2.player_id = Stat7.player_id AND Stat2.player_id = Stat8.player_id AND 
    Stat2.player_id = Stat9.player_id AND Stat2.player_id = Stat10.player_id AND 
    Stat2.player_id = Stat11.player_id AND

    Stat3.player_id = Stat4.player_id AND Stat3.player_id = Stat5.player_id AND
    Stat3.player_id = Stat6.player_id AND Stat3.player_id = Stat7.player_id AND 
    Stat3.player_id = Stat8.player_id AND Stat3.player_id = Stat9.player_id AND 
    Stat3.player_id = Stat10.player_id AND Stat3.player_id = Stat11.player_id AND

    Stat4.player_id = Stat5.player_id AND Stat4.player_id = Stat6.player_id AND 
    Stat4.player_id = Stat7.player_id AND Stat4.player_id = Stat8.player_id AND
    Stat4.player_id = Stat9.player_id AND Stat4.player_id = Stat10.player_id AND
    Stat4.player_id = Stat11.player_id AND

    Stat5.player_id = Stat6.player_id AND Stat5.player_id = Stat7.player_id AND 
    Stat5.player_id = Stat8.player_id AND Stat5.player_id = Stat9.player_id AND
    Stat5.player_id = Stat10.player_id AND Stat5.player_id = Stat11.player_id AND

    Stat6.player_id = Stat7.player_id AND Stat6.player_id = Stat8.player_id AND 
    Stat6.player_id = Stat9.player_id AND Stat6.player_id = Stat10.player_id AND
    Stat6.player_id = Stat11.player_id AND

    Stat7.player_id = Stat8.player_id AND Stat7.player_id = Stat9.player_id AND 
    Stat7.player_id = Stat10.player_id AND Stat7.player_id = Stat11.player_id AND

    Stat8.player_id = Stat9.player_id AND Stat8.player_id = Stat10.player_id AND
    Stat8.player_id = Stat11.player_id AND

    Stat9.player_id = Stat10.player_id AND Stat9.player_id = Stat11.player_id AND

    Stat10.player_id = Stat11.player_id
"""
player_play_types = pd.read_sql(Q1, conn)

# set index as 'player_name'

player_play_types.set_index('player_name',inplace=True)
player_play_types
# Out:
#                          player_id  pr_ball_handler  transition  isolation  \
# player_name
# Owen_Hamilton                  354              NaN       0.061        NaN
# Adam_Davis                       1            0.014       0.072        NaN
# Aquavius_Burks                   2            0.011       0.103      0.076
# Arshawn_Parker                   3            0.189       0.211      0.032
# Austin_Thompson                  4              NaN       0.333        NaN
# Caden_Ebeling                    5              NaN       0.071      0.005
# Corey_Wheeler                    6            0.091       0.182      0.084
# Dylan_Bennett                    7            0.031       0.108        NaN
# Jamezell_Davis_Jr                8            0.151       0.171      0.059
# Jaylen_Fordham                   9            0.079       0.185      0.083
# Juwan_Perry                     10            0.028       0.208      0.014
# Nathaniel_Collins               11            0.038       0.227      0.032
# Nathan_Kellum                   12              NaN       0.132        NaN
# Ojani_Echevarria                13            0.111       0.167        NaN
# Quinton_Armstrong               14              NaN       0.054        NaN
# Robert_Ryan                     15            0.076       0.114      0.083
# Ryan_Lowe                       16              NaN       0.033        NaN
# Adam_Radcliffe                  17            0.500         NaN        NaN
# Brad_Kruse                      18            0.106       0.141      0.165
# Brad_Perry                      19              NaN       0.019        NaN
# Brett_Czerak                    20            0.167         NaN        NaN
# Dan_Messina                     21              NaN         NaN        NaN
# Derek_Mason_II                  22            0.146       0.127      0.124
# Dimitrije_Kastratovic           23              NaN         NaN        NaN
# Jacob_Polglase                  24            0.083       0.111        NaN
# Jordan_Thomas                   25            0.183       0.127      0.079
# Jordan_Vedder                   26              NaN       0.047      0.023
# Kamal_Shasi                     27            0.172       0.069      0.129
# Kienan_Baltimore                28              NaN       0.110      0.059
# Mike_Canady                     29            0.047       0.116        NaN
# ...                            ...              ...         ...        ...
# Tristan_Ess                    481            0.006       0.083      0.006
# Taylor_Rahn                    479            0.020       0.186      0.029
# Logan_Hamilton                 472            0.037       0.093      0.084
# Caleb_Martin                   465              NaN         NaN        NaN
# Coy_Paulson                    466            0.111       0.222      0.111
# Evan_Hansen                    468            0.111       0.333      0.048
# Justin_Wilson                  470            0.152       0.087      0.109
# Ryan_Biffert                   477            0.057       0.085        NaN
# Julian_Lynch                   469              NaN         NaN        NaN
# Will_Olewinski                 483            0.007       0.126        NaN
# Tyrese_Pinson                  482            0.229       0.171      0.116
# Marcus_Kadinger                473              NaN       0.118        NaN
# Danny_Duchaj                   467              NaN         NaN        NaN
# Kelvin_Jones                   471            0.099       0.168      0.099
# Myles_Cochran                  475              NaN       0.200        NaN
# Noah_Knudsen                   476              NaN       0.176      0.059
# Will_Polczynski                484              NaN       0.058        NaN
# Matt_Shaw                      474            0.053       0.105        NaN
# Isaac_Anderson                 419              NaN         NaN        NaN
# Jequan_Pegeese                 420            0.200       0.150      0.125
# Eric_Nygaard                   417            0.005       0.151      0.041
# Deonte_Carlton                 415              NaN       0.444      0.333
# Ahmari_Dantzler                409              NaN         NaN        NaN
# Eddie_Burnett                  416              NaN       0.333      0.167
# Carlos_Campos                  412            0.050       0.314      0.100
# Garrett_Duffin                 418            0.038       0.288      0.058
# Andre_Sanchez-Amarillas        410              NaN       0.250        NaN
# Ben_Stasewich                  411              NaN       0.032        NaN
# Pat_McDonald                   424            0.342       0.235      0.137
# Shakur_Jinad                   427            0.005       0.182      0.097
#
#                          spot_up  hand_off  offensive_rebounds  off_screen  \
# player_name
# Owen_Hamilton              0.041       NaN               0.184         NaN
# Adam_Davis                 0.319       NaN               0.116         NaN
# Aquavius_Burks             0.272       NaN               0.049       0.011
# Arshawn_Parker             0.400     0.021               0.011       0.074
# Austin_Thompson            0.333       NaN                 NaN         NaN
# Caden_Ebeling              0.186       NaN               0.142       0.011
# Corey_Wheeler              0.308     0.036               0.068       0.036
# Dylan_Bennett              0.662     0.015                 NaN       0.123
# Jamezell_Davis_Jr          0.414     0.020               0.007       0.033
# Jaylen_Fordham             0.389     0.028               0.046       0.088
# Juwan_Perry                0.514     0.014               0.069       0.111
# Nathaniel_Collins          0.405     0.054               0.016       0.114
# Nathan_Kellum              0.053       NaN               0.105         NaN
# Ojani_Echevarria           0.389       NaN                 NaN       0.167
# Quinton_Armstrong          0.167       NaN               0.137       0.005
# Robert_Ryan                0.523     0.015               0.008       0.023
# Ryan_Lowe                    NaN       NaN               0.248         NaN
# Adam_Radcliffe             0.250       NaN                 NaN         NaN
# Brad_Kruse                 0.218     0.008               0.098       0.037
# Brad_Perry                 0.004     0.004               0.095         NaN
# Brett_Czerak               0.500       NaN                 NaN       0.333
# Dan_Messina                0.250       NaN                 NaN       0.250
# Derek_Mason_II             0.296     0.022               0.030       0.169
# Dimitrije_Kastratovic        NaN       NaN                 NaN         NaN
# Jacob_Polglase             0.528       NaN               0.028       0.056
# Jordan_Thomas              0.277     0.020               0.038       0.224
# Jordan_Vedder              0.419       NaN                 NaN       0.093
# Kamal_Shasi                0.353       NaN               0.043       0.086
# Kienan_Baltimore           0.224       NaN               0.041       0.068
# Mike_Canady                0.442     0.023               0.023       0.116
# ...                          ...       ...                 ...         ...
# Tristan_Ess                0.250     0.006               0.103       0.006
# Taylor_Rahn                0.431     0.049               0.029       0.137
# Logan_Hamilton             0.252     0.056               0.056       0.028
# Caleb_Martin               0.500       NaN               0.125         NaN
# Coy_Paulson                0.222       NaN                 NaN         NaN
# Evan_Hansen                0.312     0.016               0.011       0.063
# Justin_Wilson              0.391     0.022               0.109       0.043
# Ryan_Biffert               0.406     0.019               0.094       0.075
# Julian_Lynch               0.600       NaN                 NaN       0.200
# Will_Olewinski             0.378     0.015               0.067       0.230
# Tyrese_Pinson              0.205     0.019               0.043       0.050
# Marcus_Kadinger            0.412       NaN               0.059       0.059
# Danny_Duchaj               0.200       NaN               0.200         NaN
# Kelvin_Jones               0.361     0.015               0.025       0.079
# Myles_Cochran              0.300       NaN               0.100         NaN
# Noah_Knudsen               0.412       NaN                 NaN       0.176
# Will_Polczynski            0.038       NaN               0.115       0.048
# Matt_Shaw                  0.421     0.053                 NaN       0.158
# Isaac_Anderson             0.556       NaN               0.111         NaN
# Jequan_Pegeese             0.375     0.025                 NaN       0.025
# Eric_Nygaard               0.330     0.018               0.092       0.041
# Deonte_Carlton               NaN       NaN                 NaN       0.111
# Ahmari_Dantzler            0.250       NaN               0.500         NaN
# Eddie_Burnett              0.417       NaN                 NaN         NaN
# Carlos_Campos              0.252     0.050               0.022       0.157
# Garrett_Duffin             0.340     0.026               0.032       0.115
# Andre_Sanchez-Amarillas    0.750       NaN                 NaN         NaN
# Ben_Stasewich                NaN       NaN               0.161         NaN
# Pat_McDonald               0.101     0.005               0.014       0.066
# Shakur_Jinad               0.271     0.019               0.147       0.046
#
#                            cut  post_up  pr_roll_man  miscellaneous
# player_name
# Owen_Hamilton            0.143    0.367        0.082          0.122
# Adam_Davis               0.217    0.101        0.058          0.101
# Aquavius_Burks           0.141    0.179        0.043          0.114
# Arshawn_Parker             NaN      NaN          NaN          0.063
# Austin_Thompson            NaN      NaN          NaN          0.333
# Caden_Ebeling            0.131    0.355        0.049          0.049
# Corey_Wheeler            0.042    0.088        0.006          0.058
# Dylan_Bennett              NaN      NaN          NaN          0.062
# Jamezell_Davis_Jr          NaN      NaN        0.007          0.138
# Jaylen_Fordham           0.014      NaN          NaN          0.088
# Juwan_Perry              0.028      NaN          NaN          0.014
# Nathaniel_Collins        0.016      NaN          NaN          0.097
# Nathan_Kellum            0.237    0.316          NaN          0.158
# Ojani_Echevarria           NaN      NaN          NaN          0.167
# Quinton_Armstrong        0.123    0.441        0.015          0.059
# Robert_Ryan              0.023      NaN          NaN          0.136
# Ryan_Lowe                0.098    0.562        0.013          0.046
# Adam_Radcliffe             NaN      NaN          NaN          0.250
# Brad_Kruse               0.061    0.064        0.032          0.069
# Brad_Perry               0.174    0.614        0.027          0.064
# Brett_Czerak               NaN      NaN          NaN            NaN
# Dan_Messina                NaN      NaN          NaN          0.500
# Derek_Mason_II           0.030    0.004          NaN          0.052
# Dimitrije_Kastratovic      NaN      NaN        0.333          0.667
# Jacob_Polglase           0.083      NaN          NaN          0.111
# Jordan_Thomas            0.005    0.003          NaN          0.043
# Jordan_Vedder            0.023    0.047        0.163          0.186
# Kamal_Shasi                NaN    0.009          NaN          0.138
# Kienan_Baltimore         0.087    0.251        0.050          0.110
# Mike_Canady              0.023      NaN          NaN          0.209
# ...                        ...      ...          ...            ...
# Tristan_Ess              0.128    0.333        0.038          0.038
# Taylor_Rahn              0.039      NaN          NaN          0.078
# Logan_Hamilton           0.065    0.252        0.037          0.037
# Caleb_Martin             0.125      NaN          NaN          0.250
# Coy_Paulson              0.111      NaN          NaN          0.222
# Evan_Hansen              0.021      NaN          NaN          0.085
# Justin_Wilson            0.065      NaN          NaN          0.022
# Ryan_Biffert             0.151      NaN        0.009          0.104
# Julian_Lynch             0.200      NaN          NaN            NaN
# Will_Olewinski           0.052    0.007        0.052          0.067
# Tyrese_Pinson            0.085      NaN          NaN          0.081
# Marcus_Kadinger          0.118    0.059          NaN          0.176
# Danny_Duchaj               NaN    0.200          NaN          0.400
# Kelvin_Jones             0.054      NaN          NaN          0.099
# Myles_Cochran            0.300      NaN        0.100            NaN
# Noah_Knudsen             0.059      NaN          NaN          0.118
# Will_Polczynski          0.173    0.375        0.115          0.077
# Matt_Shaw                  NaN      NaN          NaN          0.211
# Isaac_Anderson           0.111      NaN        0.222            NaN
# Jequan_Pegeese           0.075      NaN          NaN          0.025
# Eric_Nygaard             0.032    0.128        0.087          0.073
# Deonte_Carlton             NaN      NaN          NaN          0.111
# Ahmari_Dantzler          0.250      NaN          NaN            NaN
# Eddie_Burnett              NaN      NaN          NaN          0.083
# Carlos_Campos            0.015      NaN          NaN          0.040
# Garrett_Duffin           0.058    0.019          NaN          0.026
# Andre_Sanchez-Amarillas    NaN      NaN          NaN            NaN
# Ben_Stasewich            0.032    0.677        0.065          0.032
# Pat_McDonald             0.038      NaN        0.005          0.057
# Shakur_Jinad             0.105    0.043        0.048          0.038
#
# [538 rows x 12 columns]

# %%
player_play_types.sort_values(by=['player_name'])
# Out:
#                          player_id  pr_ball_handler  transition  isolation  \
# player_name
# Aaron_Brown                    137              NaN         NaN        NaN
# Aaron_Crose                    119              NaN       0.082      0.020
# Aaron_Reed                     230            0.056       0.231      0.046
# Aaron_Washington               269            0.089       0.295      0.027
# Adam_Alexander                 167            0.003       0.113      0.049
# Adam_Davis                       1            0.014       0.072        NaN
# Adam_Radcliffe                  17            0.500         NaN        NaN
# Adonis_Bell                     82              NaN       0.250        NaN
# Ahmad_Eshftari                  83              NaN         NaN        NaN
# Ahmari_Dantzler                409              NaN         NaN        NaN
# Ajibola_OkeDiran               524              NaN         NaN        NaN
# Alec_Hamilton                  356            0.037       0.093      0.019
# Alex_Dykema                    213              NaN         NaN        NaN
# Alex_Eberhard                  180            0.071       0.050      0.057
# Alex_Manhardt                  464              NaN       0.095      0.027
# Alex_Ranney                    251            0.059       0.178      0.052
# Alex_Thiede                    446              NaN       0.250        NaN
# Alik_Airapetyan                120            0.440       0.120      0.040
# Amare_Thurman                   84            0.115       0.218      0.115
# Anastasios_Demogerontas        343            0.061       0.197      0.045
# Andre_Raiford_Jr.              168              NaN       0.118      0.029
# Andre_Sanchez-Amarillas        410              NaN       0.250        NaN
# Andrew_Fratzke                 430              NaN       0.120      0.007
# Andrew_Sheckell                214            0.029       0.072      0.014
# Andrew_Squires                 525            0.118       0.265        NaN
# Andrew_Wojcik                   68            0.211       0.158      0.053
# Andrew_Zelis                   344              NaN         NaN        NaN
# Angus_Bennett                  270              NaN       0.041        NaN
# Anthony_Bartman                150              NaN         NaN        NaN
# Anthony_Bonney                  85            0.250       0.250        NaN
# ...                            ...              ...         ...        ...
# Trent_Nickel                   428            0.021       0.330      0.041
# Trentin_Fouse                  480            0.061       0.133      0.010
# Trevor_Gunter                  209              NaN       0.130        NaN
# Trey_Sykes                     298            0.265       0.059      0.059
# Tristan_Baker                  118            0.016       0.288      0.040
# Tristan_Ess                    481            0.006       0.083      0.006
# Troy_Howat                     370            0.140       0.140      0.019
# Ty_Carlson                     408            0.011       0.206      0.102
# Tyler_Barman                   371              NaN         NaN        NaN
# Tyler_Ingebrigtsen             372              NaN       0.042      0.064
# Tyler_Lemke                    522              NaN       0.010      0.019
# Tyler_Young                    463              NaN       0.062      0.014
# Tyre_Dukes                     136            0.162       0.243      0.081
# Tyrel_Derrick                  210            0.063       0.188      0.063
# Tyrese_Pinson                  482            0.229       0.171      0.116
# Vannis_Smith                   311            0.066       0.212      0.100
# Vegard_Tangen                  250              NaN       0.069      0.079
# Walter_Taylor                  388              NaN         NaN        NaN
# Will_Adams                     539            0.193       0.230      0.149
# Will_Olewinski                 483            0.007       0.126        NaN
# Will_Polczynski                484              NaN       0.058        NaN
# Will_Schwartz                  523            0.500       0.500        NaN
# Zac_Holman                     212              NaN       0.059      0.059
# Zach_Anderson                  197              NaN       0.400        NaN
# Zach_Bloemker                  312            0.025       0.108      0.153
# Zach_Burk                      506              NaN       0.182        NaN
# Zach_Gorney                    389            0.007       0.101        NaN
# Zach_Hasenstein                429            0.042       0.272      0.125
# Zachary_Daniels                149              NaN         NaN        NaN
# Zack_Kvam                      211            0.055       0.187      0.055
#
#                          spot_up  hand_off  offensive_rebounds  off_screen  \
# player_name
# Aaron_Brown                0.800       NaN                 NaN         NaN
# Aaron_Crose                0.102     0.041               0.102         NaN
# Aaron_Reed                 0.370     0.028               0.019       0.056
# Aaron_Washington           0.313     0.170               0.009       0.071
# Adam_Alexander             0.153     0.003               0.083       0.028
# Adam_Davis                 0.319       NaN               0.116         NaN
# Adam_Radcliffe             0.250       NaN                 NaN         NaN
# Adonis_Bell                0.167       NaN               0.083         NaN
# Ahmad_Eshftari             0.083       NaN               0.250         NaN
# Ahmari_Dantzler            0.250       NaN               0.500         NaN
# Ajibola_OkeDiran           0.111       NaN                 NaN         NaN
# Alec_Hamilton              0.185     0.074               0.074       0.019
# Alex_Dykema                1.000       NaN                 NaN         NaN
# Alex_Eberhard              0.338     0.036               0.050       0.036
# Alex_Manhardt              0.068     0.005               0.144       0.011
# Alex_Ranney                0.311     0.007               0.074       0.052
# Alex_Thiede                0.250     0.250                 NaN       0.250
# Alik_Airapetyan            0.160     0.080                 NaN       0.080
# Amare_Thurman              0.244       NaN               0.077       0.064
# Anastasios_Demogerontas    0.341       NaN               0.129         NaN
# Andre_Raiford_Jr.          0.088       NaN               0.147       0.029
# Andre_Sanchez-Amarillas    0.750       NaN                 NaN         NaN
# Andrew_Fratzke             0.011     0.004               0.145         NaN
# Andrew_Sheckell            0.377       NaN               0.087       0.029
# Andrew_Squires             0.265     0.010               0.118       0.088
# Andrew_Wojcik              0.281     0.070                 NaN       0.105
# Andrew_Zelis               0.111       NaN               0.333         NaN
# Angus_Bennett              0.014       NaN               0.270         NaN
# Anthony_Bartman            0.500       NaN                 NaN         NaN
# Anthony_Bonney             0.500       NaN                 NaN         NaN
# ...                          ...       ...                 ...         ...
# Trent_Nickel               0.330     0.031               0.072       0.062
# Trentin_Fouse              0.510     0.031               0.041       0.071
# Trevor_Gunter              0.100       NaN               0.110         NaN
# Trey_Sykes                 0.412       NaN               0.059         NaN
# Tristan_Baker              0.280       NaN               0.088       0.040
# Tristan_Ess                0.250     0.006               0.103       0.006
# Troy_Howat                 0.411     0.065               0.009       0.131
# Ty_Carlson                 0.381     0.014               0.065       0.051
# Tyler_Barman                 NaN       NaN                 NaN         NaN
# Tyler_Ingebrigtsen         0.133     0.011               0.038       0.008
# Tyler_Lemke                0.155     0.019               0.058         NaN
# Tyler_Young                0.234     0.010               0.110       0.005
# Tyre_Dukes                 0.162     0.027               0.027       0.081
# Tyrel_Derrick              0.313       NaN               0.063         NaN
# Tyrese_Pinson              0.205     0.019               0.043       0.050
# Vannis_Smith               0.297     0.004               0.031       0.097
# Vegard_Tangen              0.376     0.020               0.040       0.030
# Walter_Taylor              1.000       NaN                 NaN         NaN
# Will_Adams                 0.248     0.031               0.019       0.012
# Will_Olewinski             0.378     0.015               0.067       0.230
# Will_Polczynski            0.038       NaN               0.115       0.048
# Will_Schwartz                NaN       NaN                 NaN         NaN
# Zac_Holman                 0.529       NaN               0.059       0.176
# Zach_Anderson              0.200       NaN                 NaN       0.400
# Zach_Bloemker              0.510     0.038                 NaN       0.102
# Zach_Burk                  0.364       NaN               0.091       0.091
# Zach_Gorney                0.312     0.007               0.094       0.029
# Zach_Hasenstein            0.292     0.045               0.054       0.125
# Zachary_Daniels              NaN       NaN                 NaN         NaN
# Zack_Kvam                  0.352     0.011               0.011         NaN
#
#                            cut  post_up  pr_roll_man  miscellaneous
# player_name
# Aaron_Brown                NaN      NaN          NaN          0.200
# Aaron_Crose              0.163    0.204        0.143          0.143
# Aaron_Reed               0.083      NaN          NaN          0.111
# Aaron_Washington           NaN      NaN          NaN          0.027
# Adam_Alexander           0.129    0.276        0.089          0.074
# Adam_Davis               0.217    0.101        0.058          0.101
# Adam_Radcliffe             NaN      NaN          NaN          0.250
# Adonis_Bell              0.083    0.167        0.167          0.083
# Ahmad_Eshftari             NaN    0.500        0.083          0.083
# Ahmari_Dantzler          0.250      NaN          NaN            NaN
# Ajibola_OkeDiran         0.222    0.444          NaN          0.222
# Alec_Hamilton            0.259    0.074        0.074          0.093
# Alex_Dykema                NaN      NaN          NaN            NaN
# Alex_Eberhard            0.068    0.135        0.071          0.089
# Alex_Manhardt            0.081    0.485        0.035          0.049
# Alex_Ranney              0.074    0.081          NaN          0.111
# Alex_Thiede                NaN      NaN          NaN            NaN
# Alik_Airapetyan            NaN      NaN          NaN          0.080
# Amare_Thurman              NaN    0.026          NaN          0.141
# Anastasios_Demogerontas  0.144    0.015        0.015          0.053
# Andre_Raiford_Jr.        0.176    0.176        0.029          0.206
# Andre_Sanchez-Amarillas    NaN      NaN          NaN            NaN
# Andrew_Fratzke           0.182    0.393        0.102          0.036
# Andrew_Sheckell          0.130      NaN        0.043          0.217
# Andrew_Squires           0.098      NaN          NaN          0.039
# Andrew_Wojcik              NaN      NaN          NaN          0.123
# Andrew_Zelis             0.222    0.167        0.056          0.111
# Angus_Bennett            0.324    0.149        0.135          0.068
# Anthony_Bartman            NaN    0.500          NaN            NaN
# Anthony_Bonney             NaN      NaN          NaN            NaN
# ...                        ...      ...          ...            ...
# Trent_Nickel             0.072      NaN          NaN          0.041
# Trentin_Fouse            0.092      NaN        0.010          0.041
# Trevor_Gunter            0.460    0.050        0.050          0.100
# Trey_Sykes               0.029      NaN          NaN          0.118
# Tristan_Baker            0.096      NaN          NaN          0.152
# Tristan_Ess              0.128    0.333        0.038          0.038
# Troy_Howat               0.065      NaN          NaN          0.019
# Ty_Carlson               0.062    0.025        0.020          0.062
# Tyler_Barman             0.286      NaN        0.286          0.429
# Tyler_Ingebrigtsen       0.148    0.375        0.129          0.053
# Tyler_Lemke              0.097    0.476        0.068          0.097
# Tyler_Young              0.115    0.211        0.091          0.148
# Tyre_Dukes               0.027    0.027          NaN          0.162
# Tyrel_Derrick              NaN      NaN          NaN          0.313
# Tyrese_Pinson            0.085      NaN          NaN          0.081
# Vannis_Smith             0.081    0.023        0.012          0.077
# Vegard_Tangen            0.129    0.059        0.119          0.079
# Walter_Taylor              NaN      NaN          NaN            NaN
# Will_Adams               0.050      NaN          NaN          0.068
# Will_Olewinski           0.052    0.007        0.052          0.067
# Will_Polczynski          0.173    0.375        0.115          0.077
# Will_Schwartz              NaN      NaN          NaN            NaN
# Zac_Holman                 NaN      NaN          NaN          0.118
# Zach_Anderson              NaN      NaN          NaN            NaN
# Zach_Bloemker              NaN      NaN          NaN          0.064
# Zach_Burk                0.182      NaN          NaN          0.091
# Zach_Gorney              0.225    0.080        0.094          0.051
# Zach_Hasenstein          0.010      NaN          NaN          0.035
# Zachary_Daniels            NaN      NaN          NaN          1.000
# Zack_Kvam                0.077      NaN          NaN          0.253
#
# [538 rows x 12 columns]

# %%
player_play_types.isnull().sum()
# Out:
# player_id               0
# pr_ball_handler       218
# transition             69
# isolation             197
# spot_up                48
# hand_off              249
# offensive_rebounds    138
# off_screen            181
# cut                   132
# post_up               277
# pr_roll_man           298
# miscellaneous          65
# dtype: int64

# %%
player_play_types.shape
# Out:
# (538, 12)

# %%
player_play_types.dropna().shape
# Out:
# (72, 12)

# %%
player_play_types.dropna(how = 'all').shape
# Out:
# (538, 12)

# %%
list(player_play_types)
# Out:
# ['player_id',
#  'pr_ball_handler',
#  'transition',
#  'isolation',
#  'spot_up',
#  'hand_off',
#  'offensive_rebounds',
#  'off_screen',
#  'cut',
#  'post_up',
#  'pr_roll_man',
#  'miscellaneous']

# %%
player_play_types.dropna(subset=['pr_ball_handler','transition','isolation','spot_up','hand_off','offensive_rebounds','off_screen','cut','post_up','pr_roll_man','miscellaneous'],how = 'all').shape
# Out:
# (535, 12)

# %%
# add player_usg_rate
Q2 = """
SELECT * FROM player_usg_rate
"""
player_usg_rate = pd.read_sql(Q2, conn)
player_usg_rate.set_index('player_name',inplace = True)
player_type_and_usg_rate = pd.merge(player_usg_rate,player_play_types,on = "player_name")
player_type_and_usg_rate
# Out:
#                               team_name   avg_poss  player_avg_poss  \
# player_name
# Adam_Davis                       Albion  83.080000         3.833333
# Aquavius_Burks                   Albion  83.080000         8.000000
# Arshawn_Parker                   Albion  83.080000         5.277778
# Austin_Thompson                  Albion  83.080000         0.600000
# Caden_Ebeling                    Albion  83.080000         7.320000
# Corey_Wheeler                    Albion  83.080000        14.000000
# Patrick_Rucker                 EastWest  98.500000        13.125000
# Dylan_Bennett                    Albion  83.080000         3.421053
# Jaylen_Fordham                   Albion  83.080000         8.640000
# Juwan_Perry                      Albion  83.080000         5.142857
# Nathaniel_Collins                Albion  83.080000         9.250000
# Nathan_Kellum                    Albion  83.080000         2.235294
# Ojani_Echevarria                 Albion  83.080000         3.000000
# Quinton_Armstrong                Albion  83.080000         8.869565
# Roland_Watkins                 EastWest  98.500000         1.833333
# Scherone_Clarke                EastWest  98.500000         2.444444
# Sherman_Brown                  EastWest  98.500000         3.727273
# Sherman_Carter                 EastWest  98.500000        20.714286
# Stanley_Thomas                 EastWest  98.500000         5.500000
# Aaron_Crose                        Knox  79.000000         4.083333
# Alik_Airapetyan                    Knox  79.000000         2.272727
# Blake_Godbold                      Knox  79.000000         9.647059
# Ryan_Shearmire                  Chicago  82.400000         1.000000
# Sam_Sustacek                    Chicago  82.400000         4.160000
# Austin_Dyer              CornellCollege  80.714286         1.714286
# Brad_Hund                CornellCollege  80.714286        10.000000
# Carron_Watt              CornellCollege  80.714286         1.000000
# Cody_Carter              CornellCollege  80.714286         4.615385
# Cooper_Kabela            CornellCollege  80.714286         3.285714
# Robert_Ryan                      Albion  83.080000         5.280000
# ...                                 ...        ...              ...
# Marcus_Kadinger                  Marian  85.080000         1.214286
# Danny_Duchaj                     Marian  85.080000         0.714286
# Kelvin_Jones                     Marian  85.080000         9.619048
# Eric_Nygaard                   Lakeland  91.000000         8.384615
# Coy_Paulson                      Marian  85.080000         0.642857
# Myles_Cochran                    Marian  85.080000         1.666667
# Noah_Knudsen                     Marian  85.080000         1.307692
# Will_Polczynski                  Marian  85.080000         4.333333
# Matt_Shaw                        Marian  85.080000         1.357143
# Will_Olewinski                   Marian  85.080000         5.625000
# Jequan_Pegeese                 Lakeland  91.000000         2.857143
# Deonte_Carlton                 Lakeland  91.000000         1.000000
# Ahmari_Dantzler                Lakeland  91.000000         1.333333
# Eddie_Burnett                  Lakeland  91.000000         1.333333
# Carlos_Campos                  Lakeland  91.000000        16.708333
# Garrett_Duffin                 Lakeland  91.000000         6.782609
# Andre_Sanchez-Amarillas        Lakeland  91.000000         2.000000
# Isaac_Anderson                 Lakeland  91.000000         0.642857
# Pat_McDonald                   Lakeland  91.000000        14.076923
# Shakur_Jinad                   Lakeland  91.000000        14.346154
# Carl_Garner                    Lakeland  91.000000         1.500000
# Joshuan_McNeal                 Lakeland  91.000000        11.272727
# Trent_Nickel                   Lakeland  91.000000         3.880000
# Kyle_Domark                    Lakeland  91.000000         2.500000
# K.J._Odom                      Lakeland  91.000000         0.909091
# Sam_Kaminski                   Lakeland  91.000000         0.727273
# Ben_Stasewich                  Lakeland  91.000000         2.066667
# Zach_Hasenstein                Lakeland  91.000000        12.000000
# Corey_Allen                    Lakeland  91.000000         2.400000
# Reggie_Nimmer                  Lakeland  91.000000         0.400000
#
#                          usg_percentage  player_id  pr_ball_handler  \
# player_name
# Adam_Davis                     0.046140          1            0.014
# Aquavius_Burks                 0.096293          2            0.011
# Arshawn_Parker                 0.063526          3            0.189
# Austin_Thompson                0.007222          4              NaN
# Caden_Ebeling                  0.088108          5              NaN
# Corey_Wheeler                  0.168512          6            0.091
# Patrick_Rucker                 0.133249         95            0.086
# Dylan_Bennett                  0.041178          7            0.031
# Jaylen_Fordham                 0.103996          9            0.079
# Juwan_Perry                    0.061902         10            0.028
# Nathaniel_Collins              0.111338         11            0.038
# Nathan_Kellum                  0.026905         12              NaN
# Ojani_Echevarria               0.036110         13            0.111
# Quinton_Armstrong              0.106759         14              NaN
# Roland_Watkins                 0.018613         96            0.045
# Scherone_Clarke                0.024817         97              NaN
# Sherman_Brown                  0.037840         98            0.024
# Sherman_Carter                 0.210297         99            0.148
# Stanley_Thomas                 0.055838        100              NaN
# Aaron_Crose                    0.051688        119              NaN
# Alik_Airapetyan                0.028769        120            0.440
# Blake_Godbold                  0.122115        121              NaN
# Ryan_Shearmire                 0.012136         48              NaN
# Sam_Sustacek                   0.050485         49              NaN
# Austin_Dyer                    0.021239         50              NaN
# Brad_Hund                      0.123894         51            0.029
# Carron_Watt                    0.012389         52              NaN
# Cody_Carter                    0.057182         53            0.033
# Cooper_Kabela                  0.040708         54              NaN
# Robert_Ryan                    0.063553         15            0.076
# ...                                 ...        ...              ...
# Marcus_Kadinger                0.014272        473              NaN
# Danny_Duchaj                   0.008395        467              NaN
# Kelvin_Jones                   0.113059        471            0.099
# Eric_Nygaard                   0.092139        417            0.005
# Coy_Paulson                    0.007556        466            0.111
# Myles_Cochran                  0.019589        475              NaN
# Noah_Knudsen                   0.015370        476              NaN
# Will_Polczynski                0.050932        484              NaN
# Matt_Shaw                      0.015951        474            0.053
# Will_Olewinski                 0.066114        483            0.007
# Jequan_Pegeese                 0.031397        420            0.200
# Deonte_Carlton                 0.010989        415              NaN
# Ahmari_Dantzler                0.014652        409              NaN
# Eddie_Burnett                  0.014652        416              NaN
# Carlos_Campos                  0.183608        412            0.050
# Garrett_Duffin                 0.074534        418            0.038
# Andre_Sanchez-Amarillas        0.021978        410              NaN
# Isaac_Anderson                 0.007064        419              NaN
# Pat_McDonald                   0.154691        424            0.342
# Shakur_Jinad                   0.157650        427            0.005
# Carl_Garner                    0.016484        413              NaN
# Joshuan_McNeal                 0.123876        421            0.008
# Trent_Nickel                   0.042637        428            0.021
# Kyle_Domark                    0.027473        423              NaN
# K.J._Odom                      0.009990        422            0.100
# Sam_Kaminski                   0.007992        426              NaN
# Ben_Stasewich                  0.022711        411              NaN
# Zach_Hasenstein                0.131868        429            0.042
# Corey_Allen                    0.026374        414            0.125
# Reggie_Nimmer                  0.004396        425              NaN
#
#                          transition  isolation  spot_up  hand_off  \
# player_name
# Adam_Davis                    0.072        NaN    0.319       NaN
# Aquavius_Burks                0.103      0.076    0.272       NaN
# Arshawn_Parker                0.211      0.032    0.400     0.021
# Austin_Thompson               0.333        NaN    0.333       NaN
# Caden_Ebeling                 0.071      0.005    0.186       NaN
# Corey_Wheeler                 0.182      0.084    0.308     0.036
# Patrick_Rucker                0.329      0.138    0.252     0.019
# Dylan_Bennett                 0.108        NaN    0.662     0.015
# Jaylen_Fordham                0.185      0.083    0.389     0.028
# Juwan_Perry                   0.208      0.014    0.514     0.014
# Nathaniel_Collins             0.227      0.032    0.405     0.054
# Nathan_Kellum                 0.132        NaN    0.053       NaN
# Ojani_Echevarria              0.167        NaN    0.389       NaN
# Quinton_Armstrong             0.054        NaN    0.167       NaN
# Roland_Watkins                0.273        NaN    0.136     0.045
# Scherone_Clarke               0.227        NaN    0.045       NaN
# Sherman_Brown                 0.024      0.195    0.146       NaN
# Sherman_Carter                0.197      0.117    0.334     0.017
# Stanley_Thomas                0.182        NaN      NaN       NaN
# Aaron_Crose                   0.082      0.020    0.102     0.041
# Alik_Airapetyan               0.120      0.040    0.160     0.080
# Blake_Godbold                 0.085      0.006    0.226     0.012
# Ryan_Shearmire                  NaN        NaN    0.500       NaN
# Sam_Sustacek                  0.087      0.010    0.087     0.010
# Austin_Dyer                     NaN      0.167      NaN       NaN
# Brad_Hund                     0.050        NaN    0.214     0.007
# Carron_Watt                     NaN        NaN    0.500       NaN
# Cody_Carter                   0.150        NaN    0.417     0.017
# Cooper_Kabela                 0.304      0.022    0.217       NaN
# Robert_Ryan                   0.114      0.083    0.523     0.015
# ...                             ...        ...      ...       ...
# Marcus_Kadinger               0.118        NaN    0.412       NaN
# Danny_Duchaj                    NaN        NaN    0.200       NaN
# Kelvin_Jones                  0.168      0.099    0.361     0.015
# Eric_Nygaard                  0.151      0.041    0.330     0.018
# Coy_Paulson                   0.222      0.111    0.222       NaN
# Myles_Cochran                 0.200        NaN    0.300       NaN
# Noah_Knudsen                  0.176      0.059    0.412       NaN
# Will_Polczynski               0.058        NaN    0.038       NaN
# Matt_Shaw                     0.105        NaN    0.421     0.053
# Will_Olewinski                0.126        NaN    0.378     0.015
# Jequan_Pegeese                0.150      0.125    0.375     0.025
# Deonte_Carlton                0.444      0.333      NaN       NaN
# Ahmari_Dantzler                 NaN        NaN    0.250       NaN
# Eddie_Burnett                 0.333      0.167    0.417       NaN
# Carlos_Campos                 0.314      0.100    0.252     0.050
# Garrett_Duffin                0.288      0.058    0.340     0.026
# Andre_Sanchez-Amarillas       0.250        NaN    0.750       NaN
# Isaac_Anderson                  NaN        NaN    0.556       NaN
# Pat_McDonald                  0.235      0.137    0.101     0.005
# Shakur_Jinad                  0.182      0.097    0.271     0.019
# Carl_Garner                   0.167        NaN    0.167     0.167
# Joshuan_McNeal                0.185      0.109    0.302     0.048
# Trent_Nickel                  0.330      0.041    0.330     0.031
# Kyle_Domark                   0.300      0.100    0.300     0.300
# K.J._Odom                     0.200      0.200    0.300       NaN
# Sam_Kaminski                  0.125        NaN      NaN       NaN
# Ben_Stasewich                 0.032        NaN      NaN       NaN
# Zach_Hasenstein               0.272      0.125    0.292     0.045
# Corey_Allen                   0.333      0.104    0.229       NaN
# Reggie_Nimmer                 0.250        NaN      NaN       NaN
#
#                          offensive_rebounds  off_screen    cut  post_up  \
# player_name
# Adam_Davis                            0.116         NaN  0.217    0.101
# Aquavius_Burks                        0.049       0.011  0.141    0.179
# Arshawn_Parker                        0.011       0.074    NaN      NaN
# Austin_Thompson                         NaN         NaN    NaN      NaN
# Caden_Ebeling                         0.142       0.011  0.131    0.355
# Corey_Wheeler                         0.068       0.036  0.042    0.088
# Patrick_Rucker                        0.029       0.014  0.019      NaN
# Dylan_Bennett                           NaN       0.123    NaN      NaN
# Jaylen_Fordham                        0.046       0.088  0.014      NaN
# Juwan_Perry                           0.069       0.111  0.028      NaN
# Nathaniel_Collins                     0.016       0.114  0.016      NaN
# Nathan_Kellum                         0.105         NaN  0.237    0.316
# Ojani_Echevarria                        NaN       0.167    NaN      NaN
# Quinton_Armstrong                     0.137       0.005  0.123    0.441
# Roland_Watkins                        0.091         NaN  0.045      NaN
# Scherone_Clarke                       0.136         NaN  0.182    0.136
# Sherman_Brown                         0.073         NaN  0.171    0.195
# Sherman_Carter                        0.045       0.059  0.010    0.024
# Stanley_Thomas                        0.273         NaN    NaN    0.364
# Aaron_Crose                           0.102         NaN  0.163    0.204
# Alik_Airapetyan                         NaN       0.080    NaN      NaN
# Blake_Godbold                         0.073       0.024  0.220    0.171
# Ryan_Shearmire                          NaN       0.500    NaN      NaN
# Sam_Sustacek                          0.163       0.010  0.183    0.260
# Austin_Dyer                           0.167         NaN    NaN    0.167
# Brad_Hund                             0.150       0.036  0.129    0.243
# Carron_Watt                             NaN         NaN  0.500      NaN
# Cody_Carter                           0.033         NaN  0.017    0.033
# Cooper_Kabela                         0.087         NaN  0.109    0.109
# Robert_Ryan                           0.008       0.023  0.023      NaN
# ...                                     ...         ...    ...      ...
# Marcus_Kadinger                       0.059       0.059  0.118    0.059
# Danny_Duchaj                          0.200         NaN    NaN    0.200
# Kelvin_Jones                          0.025       0.079  0.054      NaN
# Eric_Nygaard                          0.092       0.041  0.032    0.128
# Coy_Paulson                             NaN         NaN  0.111      NaN
# Myles_Cochran                         0.100         NaN  0.300      NaN
# Noah_Knudsen                            NaN       0.176  0.059      NaN
# Will_Polczynski                       0.115       0.048  0.173    0.375
# Matt_Shaw                               NaN       0.158    NaN      NaN
# Will_Olewinski                        0.067       0.230  0.052    0.007
# Jequan_Pegeese                          NaN       0.025  0.075      NaN
# Deonte_Carlton                          NaN       0.111    NaN      NaN
# Ahmari_Dantzler                       0.500         NaN  0.250      NaN
# Eddie_Burnett                           NaN         NaN    NaN      NaN
# Carlos_Campos                         0.022       0.157  0.015      NaN
# Garrett_Duffin                        0.032       0.115  0.058    0.019
# Andre_Sanchez-Amarillas                 NaN         NaN    NaN      NaN
# Isaac_Anderson                        0.111         NaN  0.111      NaN
# Pat_McDonald                          0.014       0.066  0.038      NaN
# Shakur_Jinad                          0.147       0.046  0.105    0.043
# Carl_Garner                           0.167         NaN  0.167      NaN
# Joshuan_McNeal                        0.069       0.036  0.073    0.044
# Trent_Nickel                          0.072       0.062  0.072      NaN
# Kyle_Domark                             NaN         NaN    NaN      NaN
# K.J._Odom                             0.100         NaN  0.100      NaN
# Sam_Kaminski                          0.250         NaN  0.250    0.250
# Ben_Stasewich                         0.161         NaN  0.032    0.677
# Zach_Hasenstein                       0.054       0.125  0.010      NaN
# Corey_Allen                           0.042       0.063  0.021      NaN
# Reggie_Nimmer                         0.250         NaN  0.250    0.250
#
#                          pr_roll_man  miscellaneous
# player_name
# Adam_Davis                     0.058          0.101
# Aquavius_Burks                 0.043          0.114
# Arshawn_Parker                   NaN          0.063
# Austin_Thompson                  NaN          0.333
# Caden_Ebeling                  0.049          0.049
# Corey_Wheeler                  0.006          0.058
# Patrick_Rucker                   NaN          0.114
# Dylan_Bennett                    NaN          0.062
# Jaylen_Fordham                   NaN          0.088
# Juwan_Perry                      NaN          0.014
# Nathaniel_Collins                NaN          0.097
# Nathan_Kellum                    NaN          0.158
# Ojani_Echevarria                 NaN          0.167
# Quinton_Armstrong              0.015          0.059
# Roland_Watkins                 0.045          0.318
# Scherone_Clarke                0.045          0.227
# Sherman_Brown                  0.049          0.122
# Sherman_Carter                   NaN          0.048
# Stanley_Thomas                 0.182            NaN
# Aaron_Crose                    0.143          0.143
# Alik_Airapetyan                  NaN          0.080
# Blake_Godbold                  0.073          0.110
# Ryan_Shearmire                   NaN            NaN
# Sam_Sustacek                   0.067          0.125
# Austin_Dyer                    0.417          0.083
# Brad_Hund                      0.050          0.093
# Carron_Watt                      NaN            NaN
# Cody_Carter                    0.167          0.133
# Cooper_Kabela                  0.130          0.022
# Robert_Ryan                      NaN          0.136
# ...                              ...            ...
# Marcus_Kadinger                  NaN          0.176
# Danny_Duchaj                     NaN          0.400
# Kelvin_Jones                     NaN          0.099
# Eric_Nygaard                   0.087          0.073
# Coy_Paulson                      NaN          0.222
# Myles_Cochran                  0.100            NaN
# Noah_Knudsen                     NaN          0.118
# Will_Polczynski                0.115          0.077
# Matt_Shaw                        NaN          0.211
# Will_Olewinski                 0.052          0.067
# Jequan_Pegeese                   NaN          0.025
# Deonte_Carlton                   NaN          0.111
# Ahmari_Dantzler                  NaN            NaN
# Eddie_Burnett                    NaN          0.083
# Carlos_Campos                    NaN          0.040
# Garrett_Duffin                   NaN          0.026
# Andre_Sanchez-Amarillas          NaN            NaN
# Isaac_Anderson                 0.222            NaN
# Pat_McDonald                   0.005          0.057
# Shakur_Jinad                   0.048          0.038
# Carl_Garner                      NaN          0.167
# Joshuan_McNeal                 0.060          0.065
# Trent_Nickel                     NaN          0.041
# Kyle_Domark                      NaN            NaN
# K.J._Odom                        NaN            NaN
# Sam_Kaminski                   0.125            NaN
# Ben_Stasewich                  0.065          0.032
# Zach_Hasenstein                  NaN          0.035
# Corey_Allen                      NaN          0.083
# Reggie_Nimmer                    NaN            NaN
#
# [531 rows x 16 columns]
